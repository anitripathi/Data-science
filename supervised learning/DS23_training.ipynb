# %%
import pandas as pd

dataset = pd.read_csv("Boston.csv")
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting data into training and testing 

x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.25)        # Divides dataset in 2 parts

# %%
x_test
# Out:
#      Unnamed: 0      crim    zn  indus  chas    nox     rm    age     dis  \
# 42           43   0.14150   0.0   6.91     0  0.448  6.169    6.6  5.7209
# 445         446  10.67180   0.0  18.10     0  0.740  6.459   94.8  1.9879
# 413         414  28.65580   0.0  18.10     0  0.597  5.155  100.0  1.5894
# 87           88   0.07151   0.0   4.49     0  0.449  6.121   56.8  3.7476
# 498         499   0.23912   0.0   9.69     0  0.585  6.019   65.3  2.4091
# ..          ...       ...   ...    ...   ...    ...    ...    ...     ...
# 484         485   2.37857   0.0  18.10     0  0.583  5.871   41.9  3.7240
# 295         296   0.12932   0.0  13.92     0  0.437  6.678   31.1  5.9604
# 415         416  18.08460   0.0  18.10     0  0.679  6.434  100.0  1.8347
# 139         140   0.54452   0.0  21.89     0  0.624  6.151   97.9  1.6687
# 66           67   0.04379  80.0   3.37     0  0.398  5.787   31.1  6.6115
#
#      rad  tax  ptratio   black  lstat
# 42     3  233     17.9  383.37   5.81
# 445   24  666     20.2   43.06  23.98
# 413   24  666     20.2  210.97  20.08
# 87     3  247     18.5  395.15   8.44
# 498    6  391     19.2  396.90  12.92
# ..   ...  ...      ...     ...    ...
# 484   24  666     20.2  370.73  13.34
# 295    4  289     16.0  396.90   6.27
# 415   24  666     20.2   27.25  29.05
# 139    4  437     21.2  396.90  18.46
# 66     4  337     16.1  396.90  10.24
#
# [127 rows x 14 columns]

# %%
x_train
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 216         217  0.04560   0.0  13.89     1  0.550  5.888  56.0  3.1121    5
# 493         494  0.17331   0.0   9.69     0  0.585  5.707  54.0  2.3817    6
# 283         284  0.01501  90.0   1.21     1  0.401  7.923  24.8  5.8850    1
# 98           99  0.08187   0.0   2.89     0  0.445  7.820  36.9  3.4952    2
# 303         304  0.10000  34.0   6.09     0  0.433  6.982  17.7  5.4917    7
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 152         153  1.12658   0.0  19.58     1  0.871  5.012  88.0  1.6102    5
# 275         276  0.09604  40.0   6.41     0  0.447  6.854  42.8  4.2673    4
# 65           66  0.03584  80.0   3.37     0  0.398  6.290  17.8  6.6115    4
# 309         310  0.34940   0.0   9.90     0  0.544  5.972  76.7  3.1025    4
# 13           14  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4
#
#      tax  ptratio   black  lstat
# 216  276     16.4  392.80  13.51
# 493  391     19.2  396.90  12.01
# 283  198     13.6  395.52   3.16
# 98   276     18.0  393.53   3.57
# 303  329     16.1  390.43   4.86
# ..   ...      ...     ...    ...
# 152  403     14.7  343.28  12.12
# 275  254     17.6  396.90   2.98
# 65   337     16.1  396.90   4.67
# 309  304     18.4  396.24   9.97
# 13   307     21.0  396.90   8.26
#
# [379 rows x 14 columns]

# %%
y_train
# Out:
# 216    23.3
# 493    21.8
# 283    50.0
# 98     43.8
# 303    33.1
#        ...
# 152    15.3
# 275    32.0
# 65     23.5
# 309    20.3
# 13     20.4
# Name: medv, Length: 379, dtype: float64

# %%
y_test
# Out:
# 42     25.3
# 445    11.8
# 413    16.3
# 87     22.2
# 498    21.2
#        ...
# 484    20.6
# 295    28.6
# 415     7.2
# 139    17.8
# 66     19.4
# Name: medv, Length: 127, dtype: float64
