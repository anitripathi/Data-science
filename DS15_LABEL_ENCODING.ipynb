# %%
import pandas as pd

df = pd.DataFrame({"name":["wcube","cat","dog","red"]})
df
# Out:
#     name
# 0  wcube
# 1    cat
# 2    dog
# 3    red

# %%
# LABEL ENCODING

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["en_name"] = le.fit_transform(df["name"])

# %%
df
# Out:
#     name  en_name
# 0  wcube        3
# 1    cat        0
# 2    dog        1
# 3    red        2

# %%
dataset = pd.read_csv("Toyota.csv")
dataset.head(5)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel  90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel  90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel  90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel  90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel  90       0.0          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
# ENCODING IN REAL DATA

la = LabelEncoder()
la.fit(dataset["Doors"])
# Out:
# LabelEncoder()

# %%
# Out:
# array([6, 1, 3, 2, 5, 4, 0])

# %%
dataset["Doors"] = la.transform(dataset["Doors"])     # encoding to value of doors

# %%
dataset["Doors"].unique()       # UNIQUE VALUE AFTER ENCODING IN DOORS
# Out:
# array([6, 1, 3, 2, 5, 4, 0])
